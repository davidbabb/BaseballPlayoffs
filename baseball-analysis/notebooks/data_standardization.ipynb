# %%
import pandas as pd
import numpy as np

# %%
master_data = pd.read_csv('..\data\processed\BattingStats.csv')

# %%
master_data.head()
# Out:
#    yearID teamID     2B    3B    HR     SB   HBP     BA    OBP    SLG    OPS
# 0    1900    BRO  199.0  81.0  26.0  274.0  81.0  0.293  0.359  0.383  0.742  \
# 1    1900    BSN  163.0  68.0  48.0  182.0  45.0  0.283  0.338  0.373  0.711
# 2    1900    CHN  202.0  51.0  33.0  189.0  65.0  0.260  0.313  0.342  0.655
# 3    1900    CIN  178.0  83.0  33.0  183.0  50.0  0.266  0.314  0.354  0.668
# 4    1900    NY1  177.0  61.0  23.0  236.0  56.0  0.279  0.337  0.357  0.694
#
#    SB%   K%    BB%  PlayoffTeam  Champ
# 0  0.0  0.0  0.079            0      0
# 1  0.0  0.0  0.072            0      0
# 2  0.0  0.0  0.064            0      0
# 3  0.0  0.0  0.061            0      0
# 4  0.0  0.0  0.071            0      0

# %%
master_data = master_data[master_data['yearID']>1902]

# %%
master_data.set_index('yearID',inplace=True)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_data = master_data.copy()

# %%
scaled_data.head()
# Out:
#        teamID     2B     3B    HR     SB   HBP     BA    OBP    SLG    OPS
# yearID
# 1903      BOS  222.0  113.0  48.0  141.0  36.0  0.272  0.307  0.392  0.699  \
# 1903      BRO  177.0   56.0  15.0  273.0  53.0  0.265  0.343  0.339  0.682
# 1903      BSN  176.0   47.0  25.0  159.0  59.0  0.245  0.309  0.318  0.627
# 1903      CHA  176.0   49.0  14.0  180.0  38.0  0.247  0.295  0.314  0.609
# 1903      CHN  191.0   62.0   9.0  259.0  50.0  0.275  0.336  0.347  0.683
#
#         SB%   K%    BB%  PlayoffTeam  Champ
# yearID
# 1903    0.0  0.0  0.049            1      1
# 1903    0.0  0.0  0.101            0      0
# 1903    0.0  0.0  0.077            0      0
# 1903    0.0  0.0  0.063            0      0
# 1903    0.0  0.0  0.080            0      0

# %%
def standardize(df):
    for i in range(1903, 2016):
        scaled_data.loc[i] = scaler.fit(scaler.loc[i])
        scaled_data.loc[i] = scaler.transform(scaler.loc[i])

# %%
cols = scaled_data.columns.drop(['teamID','PlayoffTeam','Champ'])

# %%
cols
# Out:
# Index(['2B', '3B', 'HR', 'SB', 'HBP', 'BA', 'OBP', 'SLG', 'OPS', 'SB%', 'K%',
#        'BB%'],
#       dtype='object')

# %%
master_data.head()
# Out:
#        teamID     2B     3B    HR     SB   HBP     BA    OBP    SLG    OPS
# yearID
# 1903      BOS  222.0  113.0  48.0  141.0  36.0  0.272  0.307  0.392  0.699  \
# 1903      BRO  177.0   56.0  15.0  273.0  53.0  0.265  0.343  0.339  0.682
# 1903      BSN  176.0   47.0  25.0  159.0  59.0  0.245  0.309  0.318  0.627
# 1903      CHA  176.0   49.0  14.0  180.0  38.0  0.247  0.295  0.314  0.609
# 1903      CHN  191.0   62.0   9.0  259.0  50.0  0.275  0.336  0.347  0.683
#
#         SB%   K%    BB%  PlayoffTeam  Champ
# yearID
# 1903    0.0  0.0  0.049            1      1
# 1903    0.0  0.0  0.101            0      0
# 1903    0.0  0.0  0.077            0      0
# 1903    0.0  0.0  0.063            0      0
# 1903    0.0  0.0  0.080            0      0

# %%
scaler.fit(scaled_data[cols])
# Out:
# StandardScaler()

# %%
scaled_data = scaler.transform(scaled_data[cols])

# %%
master_data.head()
# Out:
#        teamID     2B     3B    HR     SB   HBP     BA    OBP    SLG    OPS
# yearID
# 1903      BOS  222.0  113.0  48.0  141.0  36.0  0.272  0.307  0.392  0.699  \
# 1903      BRO  177.0   56.0  15.0  273.0  53.0  0.265  0.343  0.339  0.682
# 1903      BSN  176.0   47.0  25.0  159.0  59.0  0.245  0.309  0.318  0.627
# 1903      CHA  176.0   49.0  14.0  180.0  38.0  0.247  0.295  0.314  0.609
# 1903      CHN  191.0   62.0   9.0  259.0  50.0  0.275  0.336  0.347  0.683
#
#         SB%   K%    BB%  PlayoffTeam  Champ
# yearID
# 1903    0.0  0.0  0.049            1      1
# 1903    0.0  0.0  0.101            0      0
# 1903    0.0  0.0  0.077            0      0
# 1903    0.0  0.0  0.063            0      0
# 1903    0.0  0.0  0.080            0      0

# %%
scaled_data
# Out:
# array([[-0.41403939,  3.44732913, -1.18325673, ..., -1.98668873,
#         -2.57276524, -2.82600645],
#        [-1.37124015,  0.57427366, -1.77017088, ..., -1.98668873,
#         -2.57276524,  1.30191665],
#        [-1.39251128,  0.12063332, -1.5923181 , ..., -1.98668873,
#         -2.57276524, -0.60327862],
#        ...,
#        [ 0.7984149 , -0.63543391,  1.02211765, ...,  0.74737989,
#          1.50165743, -0.20636294],
#        [ 1.41527762, -1.39150114,  2.08923429, ...,  1.02040755,
#          1.17893088,  0.58746843],
#        [ 0.50061911, -1.59311907,  1.11104404, ...,  0.71325144,
#          1.88489521,  0.34931902]])

# %%
master_data.loc[1903]
# Out:
#        teamID     2B     3B    HR     SB   HBP     BA    OBP    SLG    OPS
# yearID
# 1903      BOS  222.0  113.0  48.0  141.0  36.0  0.272  0.307  0.392  0.699  \
# 1903      BRO  177.0   56.0  15.0  273.0  53.0  0.265  0.343  0.339  0.682
# 1903      BSN  176.0   47.0  25.0  159.0  59.0  0.245  0.309  0.318  0.627
# 1903      CHA  176.0   49.0  14.0  180.0  38.0  0.247  0.295  0.314  0.609
# 1903      CHN  191.0   62.0   9.0  259.0  50.0  0.275  0.336  0.347  0.683
# 1903      CIN  228.0   92.0  28.0  144.0  30.0  0.288  0.342  0.390  0.732
# 1903      CLE  231.0   95.0  31.0  175.0  40.0  0.265  0.302  0.373  0.675
# 1903      DET  162.0   91.0  12.0  128.0  46.0  0.268  0.311  0.351  0.662
# 1903      NY1  181.0   49.0  20.0  264.0  92.0  0.272  0.332  0.344  0.676
# 1903      NYA  193.0   62.0  18.0  160.0  65.0  0.249  0.305  0.330  0.635
# 1903      PHA  227.0   68.0  32.0  157.0  32.0  0.264  0.305  0.363  0.668
# ...
