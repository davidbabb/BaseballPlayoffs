# %%
import pandas as pd
import numpy as np

# %%
# In this section we will work to standardize each remaining statistic by year. The goal is to be able to compare teams in a given year vs. the league averages for the aforementioned statistics.

# %%
data = pd.read_csv('..\data\processed\BattingStats.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  yearID teamID      AB      R       H     2B    3B    HR    RBI
# 0           0    1900    BRO  4860.0  816.0  1423.0  199.0  81.0  26.0  676.0  \
# 1           1    1900    BSN  4952.0  778.0  1403.0  163.0  68.0  48.0  676.0
# 2           2    1900    CHN  4907.0  635.0  1276.0  202.0  51.0  33.0  519.0
# 3           3    1900    CIN  5026.0  703.0  1335.0  178.0  83.0  33.0  591.0
# 4           4    1900    NY1  4724.0  713.0  1317.0  177.0  61.0  23.0  564.0
#
#    ...     SH   SF     BA      PA    OBP    SLG    OPS  SB%   K%    BB%
# 0  ...   78.0  0.0  0.293  5359.0  0.359  0.383  0.742  0.0  0.0  0.079
# 1  ...  107.0  0.0  0.283  5454.0  0.338  0.373  0.711  0.0  0.0  0.072
# 2  ...  130.0  0.0  0.260  5380.0  0.313  0.342  0.655  0.0  0.0  0.064
# 3  ...  108.0  0.0  0.266  5467.0  0.314  0.354  0.668  0.0  0.0  0.061
# 4  ...   80.0  0.0  0.279  5173.0  0.337  0.357  0.694  0.0  0.0  0.071
#
# [5 rows x 25 columns]

# %%
data.drop('Unnamed: 0',axis=1,inplace=True)

# %%
data.head()
# Out:
#    yearID teamID      AB      R       H     2B    3B    HR    RBI     SB  ...
# 0    1900    BRO  4860.0  816.0  1423.0  199.0  81.0  26.0  676.0  274.0  ...  \
# 1    1900    BSN  4952.0  778.0  1403.0  163.0  68.0  48.0  676.0  182.0  ...
# 2    1900    CHN  4907.0  635.0  1276.0  202.0  51.0  33.0  519.0  189.0  ...
# 3    1900    CIN  5026.0  703.0  1335.0  178.0  83.0  33.0  591.0  183.0  ...
# 4    1900    NY1  4724.0  713.0  1317.0  177.0  61.0  23.0  564.0  236.0  ...
#
#       SH   SF     BA      PA    OBP    SLG    OPS  SB%   K%    BB%
# 0   78.0  0.0  0.293  5359.0  0.359  0.383  0.742  0.0  0.0  0.079
# 1  107.0  0.0  0.283  5454.0  0.338  0.373  0.711  0.0  0.0  0.072
# 2  130.0  0.0  0.260  5380.0  0.313  0.342  0.655  0.0  0.0  0.064
# 3  108.0  0.0  0.266  5467.0  0.314  0.354  0.668  0.0  0.0  0.061
# 4   80.0  0.0  0.279  5173.0  0.337  0.357  0.694  0.0  0.0  0.071
#
# [5 rows x 24 columns]

# %%
# Dropping remaining unnecessary columns
data.drop(columns=['AB','R','H','CS','BB','SO','SH','SF','PA','RBI'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    yearID teamID     2B    3B    HR     SB   HBP     BA    OBP    SLG    OPS
# 0    1900    BRO  199.0  81.0  26.0  274.0  81.0  0.293  0.359  0.383  0.742  \
# 1    1900    BSN  163.0  68.0  48.0  182.0  45.0  0.283  0.338  0.373  0.711
# 2    1900    CHN  202.0  51.0  33.0  189.0  65.0  0.260  0.313  0.342  0.655
# 3    1900    CIN  178.0  83.0  33.0  183.0  50.0  0.266  0.314  0.354  0.668
# 4    1900    NY1  177.0  61.0  23.0  236.0  56.0  0.279  0.337  0.357  0.694
#
#    SB%   K%    BB%
# 0  0.0  0.0  0.079
# 1  0.0  0.0  0.072
# 2  0.0  0.0  0.064
# 3  0.0  0.0  0.061
# 4  0.0  0.0  0.071

# %%
data.set_index(['yearID','teamID'])
# Out:
#                   2B    3B     HR     SB   HBP     BA    OBP    SLG    OPS
# yearID teamID
# 1900   BRO     199.0  81.0   26.0  274.0  81.0  0.293  0.359  0.383  0.742  \
#        BSN     163.0  68.0   48.0  182.0  45.0  0.283  0.338  0.373  0.711
#        CHN     202.0  51.0   33.0  189.0  65.0  0.260  0.313  0.342  0.655
#        CIN     178.0  83.0   33.0  183.0  50.0  0.266  0.314  0.354  0.668
#        NY1     177.0  61.0   23.0  236.0  56.0  0.279  0.337  0.357  0.694
# ...              ...   ...    ...    ...   ...    ...    ...    ...    ...
# 2015   SLN     288.0  39.0  137.0   69.0  66.0  0.253  0.323  0.394  0.717
#        TBA     278.0  32.0  167.0   87.0  84.0  0.252  0.318  0.406  0.724
#        TEX     279.0  32.0  172.0  101.0  76.0  0.257  0.327  0.413  0.740
#        TOR     308.0  17.0  232.0   88.0  54.0  0.269  0.341  0.457  0.798
#        WAS     265.0  13.0  177.0   57.0  44.0  0.251  0.320  0.403  0.723
#
#                  SB%     K%    BB%
# yearID teamID
# ...

# %%
normalized_data = pd.DataFrame()

# %%
len(data[data['yearID']==1900].index)
# Out:
# 8

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data.set_index(['yearID','teamID'])
# Out:
#                   2B    3B     HR     SB   HBP     BA    OBP    SLG    OPS
# yearID teamID
# 1900   BRO     199.0  81.0   26.0  274.0  81.0  0.293  0.359  0.383  0.742  \
#        BSN     163.0  68.0   48.0  182.0  45.0  0.283  0.338  0.373  0.711
#        CHN     202.0  51.0   33.0  189.0  65.0  0.260  0.313  0.342  0.655
#        CIN     178.0  83.0   33.0  183.0  50.0  0.266  0.314  0.354  0.668
#        NY1     177.0  61.0   23.0  236.0  56.0  0.279  0.337  0.357  0.694
# ...              ...   ...    ...    ...   ...    ...    ...    ...    ...
# 2015   SLN     288.0  39.0  137.0   69.0  66.0  0.253  0.323  0.394  0.717
#        TBA     278.0  32.0  167.0   87.0  84.0  0.252  0.318  0.406  0.724
#        TEX     279.0  32.0  172.0  101.0  76.0  0.257  0.327  0.413  0.740
#        TOR     308.0  17.0  232.0   88.0  54.0  0.269  0.341  0.457  0.798
#        WAS     265.0  13.0  177.0   57.0  44.0  0.251  0.320  0.403  0.723
#
#                  SB%     K%    BB%
# yearID teamID
# ...

# %%
scaled_data = data.groupby(level=0).apply(lambda x: pd.DataFrame(scaler.fit_transform(x),columns=x.columns).round(5))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22916\647978189.py in ?()
# ----> 1 scaled_data = data.groupby(level=0).apply(lambda x: pd.DataFrame(scaler.fit_transform(x),columns=x.columns).round(5))
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\groupby\groupby.py in ?(self, func, *args, **kwargs)
#    1350         # ignore SettingWithCopy here in case the user mutates
#    1351         with option_context("mode.chained_assignment", None):
#    1352             try:
#    1353                 result = self._python_apply_general(f, self._selected_obj)
# -> 1354             except TypeError:
#    1355                 # gh-20949
#    1356                 # try again, with .apply acting as a filtering
# ...

# %%
playoff_teams = pd.read_csv('..\data\\raw\SeriesPost.csv')

# %%
playoff_teams.head()

# %%
timeIndex = playoff_teams[playoff_teams['yearID']<1900].index

# %%
playoff_teams.drop(timeIndex,inplace=True)

# %%
playoff_teams.set_index('yearID')
# Out:
#         round teamIDwinner lgIDwinner teamIDloser lgIDloser  wins  losses
# yearID
# 1903       WS          BOS         AL         PIT        NL     5       3  \
# 1905       WS          NY1         NL         PHA        AL     4       1
# 1906       WS          CHA         AL         CHN        NL     4       2
# 1907       WS          CHN         NL         DET        AL     4       0
# 1908       WS          CHN         NL         DET        AL     4       1
# ...       ...          ...        ...         ...       ...   ...     ...
# 2015     NLWC          CHN         NL         PIT        NL     1       0
# 2015     NLCS          NYN         NL         CHN        NL     4       0
# 2015    NLDS1          CHN         NL         SLN        NL     3       1
# 2015    NLDS2          NYN         NL         LAN        NL     3       2
# 2015       WS          KCA         AL         NYN        NL     4       1
#
#         ties
# yearID
# 1903       0
# 1905       0
# 1906       0
# ...

# %%
data.set_index('yearID')
# Out:
#        teamID     2B    3B     HR     SB   HBP     BA    OBP    SLG    OPS
# yearID
# 1900      BRO  199.0  81.0   26.0  274.0  81.0  0.293  0.359  0.383  0.742  \
# 1900      BSN  163.0  68.0   48.0  182.0  45.0  0.283  0.338  0.373  0.711
# 1900      CHN  202.0  51.0   33.0  189.0  65.0  0.260  0.313  0.342  0.655
# 1900      CIN  178.0  83.0   33.0  183.0  50.0  0.266  0.314  0.354  0.668
# 1900      NY1  177.0  61.0   23.0  236.0  56.0  0.279  0.337  0.357  0.694
# ...       ...    ...   ...    ...    ...   ...    ...    ...    ...    ...
# 2015      SLN  288.0  39.0  137.0   69.0  66.0  0.253  0.323  0.394  0.717
# 2015      TBA  278.0  32.0  167.0   87.0  84.0  0.252  0.318  0.406  0.724
# 2015      TEX  279.0  32.0  172.0  101.0  76.0  0.257  0.327  0.413  0.740
# 2015      TOR  308.0  17.0  232.0   88.0  54.0  0.269  0.341  0.457  0.798
# 2015      WAS  265.0  13.0  177.0   57.0  44.0  0.251  0.320  0.403  0.723
#
#           SB%     K%    BB%  PlayoffTeam
# yearID
# ...

# %%
joined = data.join(playoff_teams,on='yearID')

# %%
new = data.assign(PlayoffTeam=data[data['yearID']==1907]['teamID'].isin(playoff_teams[playoff_teams['yearID']==1907]).astype(int))

# %%
def playoffs(team):
    for i in range(1900,2016):
        if data[data['teamID']==team][data['yearID']==i]['teamID'].equals(playoff_teams[playoff_teams['yearID']==i]['teamIDwinner']):
            return 1
        elif data[data['teamID']==team][data['yearID']==i]['teamID'].equals(playoff_teams[playoff_teams['yearID']==i]['teamIDloser']):
            return 1
        else:
            return 0

# %%
# gotta be inside a loop somehow
data['PlayoffTeam'] = data['teamID'].apply(lambda x: playoffs(x))
# Out:
# C:\Users\dbabb\AppData\Local\Temp\ipykernel_4700\1281900835.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if data[data['teamID']==team][data['yearID']==i]['teamID'].equals(playoff_teams[playoff_teams['yearID']==i]['teamIDwinner']):
# C:\Users\dbabb\AppData\Local\Temp\ipykernel_4700\1281900835.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   elif data[data['teamID']==team][data['yearID']==i]['teamID'].equals(playoff_teams[playoff_teams['yearID']==i]['teamIDloser']):
# C:\Users\dbabb\AppData\Local\Temp\ipykernel_4700\1281900835.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if data[data['teamID']==team][data['yearID']==i]['teamID'].equals(playoff_teams[playoff_teams['yearID']==i]['teamIDwinner']):
# C:\Users\dbabb\AppData\Local\Temp\ipykernel_4700\1281900835.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ...

# %%
data[data['yearID']==1903]
# Out:
#     yearID teamID     2B     3B    HR     SB   HBP     BA    OBP    SLG
# 40    1903    BOS  222.0  113.0  48.0  141.0  36.0  0.272  0.307  0.392  \
# 41    1903    BRO  177.0   56.0  15.0  273.0  53.0  0.265  0.343  0.339
# 42    1903    BSN  176.0   47.0  25.0  159.0  59.0  0.245  0.309  0.318
# 43    1903    CHA  176.0   49.0  14.0  180.0  38.0  0.247  0.295  0.314
# 44    1903    CHN  191.0   62.0   9.0  259.0  50.0  0.275  0.336  0.347
# 45    1903    CIN  228.0   92.0  28.0  144.0  30.0  0.288  0.342  0.390
# 46    1903    CLE  231.0   95.0  31.0  175.0  40.0  0.265  0.302  0.373
# 47    1903    DET  162.0   91.0  12.0  128.0  46.0  0.268  0.311  0.351
# 48    1903    NY1  181.0   49.0  20.0  264.0  92.0  0.272  0.332  0.344
# 49    1903    NYA  193.0   62.0  18.0  160.0  65.0  0.249  0.305  0.330
# 50    1903    PHA  227.0   68.0  32.0  157.0  32.0  0.264  0.305  0.363
# 51    1903    PHI  186.0   62.0  12.0  120.0  39.0  0.268  0.315  0.341
# ...

# %%
new.head()

# %%
playoff_teams.head()
# Out:
#     yearID round teamIDwinner lgIDwinner teamIDloser lgIDloser  wins  losses
# 8     1903    WS          BOS         AL         PIT        NL     5       3  \
# 9     1905    WS          NY1         NL         PHA        AL     4       1
# 10    1906    WS          CHA         AL         CHN        NL     4       2
# 11    1907    WS          CHN         NL         DET        AL     4       0
# 12    1908    WS          CHN         NL         DET        AL     4       1
#
#     ties
# 8      0
# 9      0
# 10     0
# 11     0
# 12     0

# %%
data[data['teamID']=='BAL'][data['yearID']==2012]['teamID'].isin(playoff_teams[playoff_teams['yearID']==2012]['teamIDwinner'])
# Out:
# C:\Users\dbabb\AppData\Local\Temp\ipykernel_4700\249754030.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data[data['teamID']=='BAL'][data['yearID']==2012]['teamID'].isin(playoff_teams[playoff_teams['yearID']==2012]['teamIDwinner'])
# 2312    True
# Name: teamID, dtype: bool
